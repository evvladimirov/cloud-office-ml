# %% [markdown]
# # Office cloud task for Google Cloud ML Setup and Deployment
#
# This notebook sets up the necessary Google Cloud Platform (GCP) services for machine learning deployment. It configures:
#
# - **Google Cloud Storage (GCS)** - For storing model artifacts and data
# - **Google Cloud AI Platform** - For model training and deployment
# - **Project configuration** - Sets up the GCP project and region
#
# The setup process includes creating a storage bucket and initializing the AI Platform with the necessary credentials and configurations.

# %%
# Google Cloud Platform libraries
from google.cloud import aiplatform  # Vertex AI for model training and deployment
from google.cloud import storage     # Google Cloud Storage for data and model artifacts

import pandas as pd                  # For data manipulation

# %%
# Configure GCP project settings
# This cell sets up the basic configuration for your GCP project
# These settings will be used throughout the notebook for all GCP operations

# Get the current GCP project ID from gcloud CLI
# This ensures we're working with the correct project
project = !gcloud config get-value project
PROJECT_ID = project[0]

# Set the region for AI Platform services
LOCATION = 'us-central1'

# Define the storage bucket name for storing model artifacts
# This bucket will store our trained models and preprocessing objects
BUCKET = 'cloud-office-ml-bucket'

# %%
# Initialize Google Cloud service clients
# These clients will be used to interact with GCS and BigQuery services

gcs = storage.Client(project = PROJECT_ID)  # Google Cloud Storage client

# %%
# Create or verify Google Cloud Storage bucket
# This bucket will store model artifacts, training data, and other ML assets

if not gcs.lookup_bucket(BUCKET):
    # Create new bucket if it doesn't exist
    bucketDef = gcs.bucket(BUCKET)
    bucket = gcs.create_bucket(bucketDef, project=PROJECT_ID, location=LOCATION)
    print(f'Created Bucket: {gcs.lookup_bucket(BUCKET).name}')
else:
    # Use existing bucket if it already exists
    bucket = gcs.bucket(BUCKET)
    print(f'Bucket already exist: {bucket.name}')
# Out:
# Bucket already exist: cloud-office-ml-bucket

# %%
# Create bucket URI for AI Platform configuration
# This URI format is required by Google Cloud AI Platform services

BUCKET_URI = f"gs://{bucket.name}"

# %%
# Initialize Google Cloud AI Platform
# This sets up the AI Platform with your project settings and staging bucket
# The staging bucket is where training artifacts and model files will be stored

aiplatform.init(project=PROJECT_ID, location=LOCATION, staging_bucket=BUCKET_URI)

# %%
MODEL_ARTIFACT_DIR = "coml-artifact-dir"
REPOSITORY = "coml-repository-name"
IMAGE = "coml-image-name"
MODEL_DISPLAY_NAME = "coml-model-display-name"

# Set the defaults if no names were specified
if MODEL_ARTIFACT_DIR == "[your-artifact-directory]":
    MODEL_ARTIFACT_DIR = "custom-container-prediction-model"

if REPOSITORY == "[your-repository-name]":
    REPOSITORY = "custom-container-prediction"

if IMAGE == "[your-image-name]":
    IMAGE = "sklearn-fastapi-server"

if MODEL_DISPLAY_NAME == "[your-model-display-name]":
    MODEL_DISPLAY_NAME = "sklearn-custom-container"

# %%
# %mkdir app

# %%
# %%writefile app/preprocess.py

import pandas as pd

class Preprocessor():
    def __init__(self):
        self.numerical = ['tenure', 'monthlycharges', 'totalcharges']
        self.categorical = [
            'gender',
            'seniorcitizen',
            'partner',
            'dependents',
            'phoneservice',
            'multiplelines',
            'internetservice',
            'onlinesecurity',
            'onlinebackup',
            'deviceprotection',
            'techsupport',
            'streamingtv',
            'streamingmovies',
            'contract',
            'paperlessbilling',
            'paymentmethod',
        ]

    def preprocess(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        Preprocess the raw dataframe.
        Args:
            df_raw: Raw dataframe to preprocess.

        Returns:
            Preprocessed dataframe.
        """

        df.columns = [col.lower().replace(' ', '_') for col in df.columns]
        df = df[self.categorical + self.numerical + ['churn']]
        df.churn = (df.churn == 'Yes').astype(int)

        for col in df.columns:
            if df[col].dtype == 'object':
                df[col] = df[col].str.lower().str.replace(' ', '_')
                
        df.totalcharges = pd.to_numeric(df.totalcharges, errors='coerce')
        df[self.numerical] = df[self.numerical].fillna(0)

        return df
# Out:
# Writing app/preprocess.py

# %%
import pickle

import joblib
from app.preprocess import Preprocessor
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression

dv = DictVectorizer()
prp = Preprocessor()

BUCKET = 'cloud-office-ml-bucket'

df_raw = pd.read_csv(f'gs://{BUCKET}/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df_processed = prp.preprocess(df_raw)

y_train = df_processed['churn']
X_train = df_processed.drop('churn', axis=1)

train_dict = X_train.to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

model = LogisticRegression(solver='liblinear')
model.fit(X_train, y_train)

joblib.dump(model, "model.joblib")
with open("preprocessor.pkl", "wb") as f:
    pickle.dump(prp, f)
# Out:
# /home/ev/cloud-office-ml/app/preprocess.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.churn = (df.churn == 'Yes').astype(int)
# /home/ev/cloud-office-ml/app/preprocess.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].str.lower().str.replace(' ', '_')
# /home/ev/cloud-office-ml/app/preprocess.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.totalcharges = pd.to_numeric(df.totalcharges, errors='coerce')
# /home/ev/cloud-office-ml/app/preprocess.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[self.numerical] = df[self.numerical].fillna(0)

# %% [markdown]
# Upload model artifacts - model itself and preprocessor

# %%
# !gsutil cp model.joblib preprocessor.pkl {BUCKET_URI}/{MODEL_ARTIFACT_DIR}/
# Out:
# Copying file://model.joblib [Content-Type=application/octet-stream]...
# Copying file://preprocessor.pkl [Content-Type=application/octet-stream]...
# - [2 files][  1.6 KiB/  1.6 KiB]
# Operation completed over 2 objects/1.6 KiB.

# %% [markdown]
# Build a FastAPI server

# %%
# %%writefile app/main.py

from fastapi import FastAPI, Request
from typing import Literal
from pydantic import BaseModel, Field

import joblib
import pickle
import pandas as pd

from google.cloud import storage


AIP_HEALTH_ROUTE = '/health'
AIP_PREDICT_ROUTE = '/predict'
PROBABILITY_THRESHOLD = 0.5

class Customer(BaseModel):
    gender: Literal["male", "female"]
    seniorcitizen: Literal[0, 1]
    partner: Literal["yes", "no"]
    dependents: Literal["yes", "no"]
    phoneservice: Literal["yes", "no"]
    multiplelines: Literal["no", "yes", "no_phone_service"]
    internetservice: Literal["dsl", "fiber_optic", "no"]
    onlinesecurity: Literal["no", "yes", "no_internet_service"]
    onlinebackup: Literal["no", "yes", "no_internet_service"]
    deviceprotection: Literal["no", "yes", "no_internet_service"]
    techsupport: Literal["no", "yes", "no_internet_service"]
    streamingtv: Literal["no", "yes", "no_internet_service"]
    streamingmovies: Literal["no", "yes", "no_internet_service"]
    contract: Literal["month-to-month", "one_year", "two_year"]
    paperlessbilling: Literal["yes", "no"]
    paymentmethod: Literal[
        "electronic_check",
        "mailed_check",
        "bank_transfer_(automatic)",
        "credit_card_(automatic)",
    ]
    tenure: int = Field(..., ge=0)
    monthlycharges: float = Field(..., ge=0.0)
    totalcharges: float = Field(..., ge=0.0)

class PredictResponse(BaseModel):
    churn_probability: float
    churn: bool

app = FastAPI()
gcs_client = storage.Client()

with open("preprocessor.pkl", 'wb') as preprocessor_f, open("model.joblib", 'wb') as model_f:
    gcs_client.download_blob_to_file(
        f"{BUCKET_URI}/{MODEL_ARTIFACT_DIR}/preprocessor.pkl", preprocessor_f
    )
    gcs_client.download_blob_to_file(
        f"{BUCKET_URI}/{MODEL_ARTIFACT_DIR}/model.joblib", model_f
    )

with open("preprocessor.pkl", "rb") as f:
    preprocessor = pickle.load(f)

_model = joblib.load("model.joblib")
_preprocessor = preprocessor


@app.get(AIP_HEALTH_ROUTE, status_code=200)
def health():
    return {}


@app.post(AIP_PREDICT_ROUTE)
async def predict(request: Request):
    body = await request.json()

    customer_data = body["customer_data"]
    inputs = pd.DataFrame(customer_data)
    preprocessed_inputs = _preprocessor.preprocess(inputs)
    outputs = _model.predict_proba(preprocessed_inputs)

    return PredictResponse(
        churn_probability=outputs[1],
        churn=outputs[1] >= PROBABILITY_THRESHOLD
    )
# Out:
# Overwriting app/main.py

# %%
# %%writefile test_request.py

import requests

url = 'http://localhost:8086/predict'

customer = {
    'gender': 'female',
    'seniorcitizen': 0,
    'partner': 'yes',
    'dependents': 'no',
    'phoneservice': 'no',
    'multiplelines': 'no_phone_service',
    'internetservice': 'dsl',
    'onlinesecurity': 'no',
    'onlinebackup': 'yes',
    'deviceprotection': 'no',
    'techsupport': 'no',
    'streamingtv': 'no',
    'streamingmovies': 'no',
    'contract': 'month-to-month',
    'paperlessbilling': 'yes',
    'paymentmethod': 'electronic_check',
    'tenure': 1,
    'monthlycharges': 29.85,
    'totalcharges': 29.85
}

response = requests.post(url, json=customer)

predictions = response.json()

if predictions['churn']:
    print('customer is likely to churn, send promo')
else:
    print('customer is not likely to churn')
# Out:
# Overwriting test_request.py

# %%
# %%writefile Dockerfile
#
# FROM python:3.12-slim
#
# # Install uv
# COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /usr/local/bin/
#
# # Set working directory
# WORKDIR /app
#
# # Copy dependency files
# COPY pyproject.toml uv.lock ./
#
# # Install dependencies
# RUN uv sync --frozen
#
# # Install fastapi
# RUN uv add fastapi
#
# # Install uvicorn separately if needed
# RUN uv add uvicorn[standard]
#
# # Copy application code
# COPY app/ ./app/
#
# # Expose port (if needed)
# EXPOSE 8086
#
# #Run the FastAPI application
# CMD ["uv", "run", "uvicorn", "app.main:app", "--host", "0.0.0.0", "--port", "8086"]
# Out:
# Overwriting Dockerfile

# %%
# !docker build -t gcr.io/cloud-office-ml-project/churn-prediction-fastapi:latest .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 582B                                       0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.2s
#  => [internal] load metadata for docker.io/library/python:3.12-slim        0.2s
# [+] Building 0.2s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 582B                                       0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.2s
#  => [internal] load metadata for docker.io/library/python:3.12-slim        0.2s
# [+] Building 0.4s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 582B                                       0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.3s
#  => [internal] load metadata for docker.io/library/python:3.12-slim        0.2s
# [+] Building 0.4s (3/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 582B                                       0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.3s
#  => [internal] load metadata for docker.io/library/python:3.12-slim        0.2s
# [+] Building 0.4s (15/15) FINISHED                               docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 582B                                       0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.3s
#  => [internal] load metadata for docker.io/library/python:3.12-slim        0.2s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:f459f6f73a8c4ef5d69f4e6fbbdb8  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 286B                                          0.0s
#  => [stage-0 1/8] FROM docker.io/library/python:3.12-slim@sha256:b03eed49  0.0s
#  => CACHED [stage-0 2/8] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx  0.0s
#  => CACHED [stage-0 3/8] WORKDIR /app                                      0.0s
#  => CACHED [stage-0 4/8] COPY pyproject.toml uv.lock ./                    0.0s
#  => CACHED [stage-0 5/8] RUN uv sync --frozen                              0.0s
#  => CACHED [stage-0 6/8] RUN uv add fastapi                                0.0s
#  => CACHED [stage-0 7/8] RUN uv add uvicorn[standard]                      0.0s
#  => CACHED [stage-0 8/8] COPY app/ ./app/                                  0.0s
#  => exporting to image                                                     0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:3354f682d124ed606d357ac682eb25f8ff6df95586e02  0.0s
#  => => naming to gcr.io/cloud-office-ml-project/churn-prediction-fastapi:  0.0s

# %%
REPOSITORY = "cloud-office-ml-docker-repo"
! gcloud artifacts repositories create {REPOSITORY} --repository-format=docker --location={LOCATION} --description="Docker repository"
! gcloud artifacts repositories list
# Out:
# ERROR: (gcloud.artifacts.repositories.create) ALREADY_EXISTS: the repository already exists
# Listing items under project office-cloud-project, across all locations.
#
#                                                                             ARTIFACT_REGISTRY
# REPOSITORY                   FORMAT  MODE                 DESCRIPTION        LOCATION     LABELS  ENCRYPTION          CREATE_TIME          UPDATE_TIME          SIZE (MB)
# cloud-office-ml-docker-repo  DOCKER  STANDARD_REPOSITORY  Docker repository  us-central1          Google-managed key  2025-10-23T11:30:07  2025-10-23T11:30:07  0

# %%
# !gcloud builds submit --region={LOCATION} --tag={LOCATION}-docker.pkg.dev/{PROJECT_ID}/{REPOSITORY}/{IMAGE}
# Out:
# Creating temporary archive of 12 file(s) totalling 479.1 KiB before compression.
# Some files were not included in the source upload.
#
# Check the gcloud log [/home/ev/.config/gcloud/logs/2025.10.23/11.52.52.541188.log] to see which files and the contents of the
# default gcloudignore file used (see `$ gcloud topic gcloudignore` to learn
# more).
#
# Uploading tarball of [.] to [gs://office-cloud-project_cloudbuild/source/1761209572.666546-005d921acf8d4527b70d43834dfbfb47.tgz]
# Created [https://cloudbuild.googleapis.com/v1/projects/office-cloud-project/locations/us-central1/builds/f47623eb-2516-42d7-867a-88f23b2a4e9a].
# Logs are available at [ https://console.cloud.google.com/cloud-build/builds;region=us-central1/f47623eb-2516-42d7-867a-88f23b2a4e9a?project=485739110011 ].
# Waiting for build to complete. Polling interval: 1 second(s).
# ----------------------------- REMOTE BUILD OUTPUT ------------------------------
# starting build "f47623eb-2516-42d7-867a-88f23b2a4e9a"
#
# FETCHSOURCE
# Fetching storage object: gs://office-cloud-project_cloudbuild/source/1761209572.666546-005d921acf8d4527b70d43834dfbfb47.tgz#1761209574035468
# Copying gs://office-cloud-project_cloudbuild/source/1761209572.666546-005d921acf8d4527b70d43834dfbfb47.tgz#1761209574035468...
# / [1 files][146.6 KiB/146.6 KiB]
# Operation completed over 1 objects/146.6 KiB.
# BUILD
# Already have image (with digest): gcr.io/cloud-builders/docker
# Sending build context to Docker daemon  501.2kB
# Step 1/10 : FROM python:3.12-slim
# 3.12-slim: Pulling from library/python
# 38513bd72563: Pulling fs layer
# f2a111092025: Pulling fs layer
# 79f2dc6dd7d8: Pulling fs layer
# d2876f169c02: Pulling fs layer
# d2876f169c02: Waiting
# f2a111092025: Verifying Checksum
# f2a111092025: Download complete
# d2876f169c02: Verifying Checksum
# d2876f169c02: Download complete
# 79f2dc6dd7d8: Verifying Checksum
# 79f2dc6dd7d8: Download complete
# 38513bd72563: Verifying Checksum
# 38513bd72563: Download complete
# 38513bd72563: Pull complete
# f2a111092025: Pull complete
# 79f2dc6dd7d8: Pull complete
# d2876f169c02: Pull complete
# Digest: sha256:b03eed4944bc758029e0506ec41acb6a4be6d1b2b875d6e04ac4759db343a370
# Status: Downloaded newer image for python:3.12-slim
#  ---> 324231aabbd8
# Step 2/10 : COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /usr/local/bin/
# latest: Pulling from astral-sh/uv
# 0daf2b1a974d: Pulling fs layer
# 99df4935c979: Pulling fs layer
# 99df4935c979: Verifying Checksum
# 99df4935c979: Download complete
# 0daf2b1a974d: Verifying Checksum
# 0daf2b1a974d: Download complete
# 0daf2b1a974d: Pull complete
# 99df4935c979: Pull complete
# Digest: sha256:f459f6f73a8c4ef5d69f4e6fbbdb8af751d6fa40ec34b39a1ab469acd6e289b7
# Status: Downloaded newer image for ghcr.io/astral-sh/uv:latest
#  ---> c6738ab1e892
# Step 3/10 : WORKDIR /app
#  ---> Running in 66fb9fac1501
# Removing intermediate container 66fb9fac1501
#  ---> d42eebc982d0
# Step 4/10 : COPY pyproject.toml uv.lock ./
#  ---> df8fae127b24
# Step 5/10 : RUN uv sync --frozen
#  ---> Running in ada1ced547a0
# Using CPython 3.12.12 interpreter at: /usr/local/bin/python3
# Creating virtual environment at: .venv
# Downloading jedi (1.5MiB)
# Downloading pygments (1.2MiB)
# Downloading shapely (3.0MiB)
# Downloading pydantic-core (2.0MiB)
# Downloading widgetsnbextension (2.1MiB)
# Downloading setuptools (1.1MiB)
# Downloading aiohttp (1.7MiB)
# Downloading pandas (11.8MiB)
# Downloading numpy (15.9MiB)
# Downloading jupyterlab (11.7MiB)
# Downloading google-cloud-aiplatform (7.7MiB)
# Downloading grpcio (6.3MiB)
# Downloading babel (9.7MiB)
# Downloading scikit-learn (9.0MiB)
# Downloading notebook (13.7MiB)
# Downloading scipy (34.0MiB)
# Downloading debugpy (4.1MiB)
#  Downloading aiohttp
#  Downloading pydantic-core
#  Downloading widgetsnbextension
#  Downloading pygments
#  Downloading shapely
#  Downloading setuptools
#  Downloading debugpy
#  Downloading grpcio
#  Downloading babel
#  Downloading scikit-learn
#  Downloading jupyterlab
#  Downloading notebook
#  Downloading numpy
#  Downloading google-cloud-aiplatform
#  Downloading jedi
#  Downloading scipy
#  Downloading pandas
# Prepared 145 packages in 6.48s
# Installed 145 packages in 510ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.1
#  + aiosignal==1.4.0
#  + annotated-types==0.7.0
#  + anyio==4.11.0
#  + argon2-cffi==25.1.0
#  + argon2-cffi-bindings==25.1.0
#  + arrow==1.4.0
#  + asttokens==3.0.0
#  + async-lru==2.0.5
#  + attrs==25.4.0
#  + babel==2.17.0
#  + beautifulsoup4==4.14.2
#  + bleach==6.2.0
#  + cachetools==6.2.1
#  + certifi==2025.10.5
#  + cffi==2.0.0
#  + charset-normalizer==3.4.4
#  + comm==0.2.3
#  + debugpy==1.8.17
#  + decorator==5.2.1
#  + defusedxml==0.7.1
#  + docstring-parser==0.17.0
#  + executing==2.2.1
#  + fastjsonschema==2.21.2
#  + fqdn==1.5.1
#  + frozenlist==1.8.0
#  + fsspec==2025.9.0
#  + gcsfs==2025.9.0
#  + google-api-core==2.26.0
#  + google-auth==2.41.1
#  + google-auth-oauthlib==1.2.2
#  + google-cloud-aiplatform==1.121.0
#  + google-cloud-bigquery==3.38.0
#  + google-cloud-core==2.4.3
#  + google-cloud-resource-manager==1.15.0
#  + google-cloud-storage==2.19.0
#  + google-crc32c==1.7.1
#  + google-genai==1.46.0
#  + google-resumable-media==2.7.2
#  + googleapis-common-protos==1.71.0
#  + grpc-google-iam-v1==0.14.3
#  + grpcio==1.76.0
#  + grpcio-status==1.76.0
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + idna==3.11
#  + ipykernel==7.0.1
#  + ipython==9.6.0
#  + ipython-pygments-lexers==1.1.1
#  + ipywidgets==8.1.7
#  + isoduration==20.11.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + joblib==1.5.2
#  + json5==0.12.1
#  + jsonpointer==3.0.0
#  + jsonschema==4.25.1
#  + jsonschema-specifications==2025.9.1
#  + jupyter==1.1.1
#  + jupyter-client==8.6.3
#  + jupyter-console==6.6.3
#  + jupyter-core==5.9.1
#  + jupyter-events==0.12.0
#  + jupyter-lsp==2.3.0
#  + jupyter-server==2.17.0
#  + jupyter-server-terminals==0.5.3
#  + jupyterlab==4.4.9
#  + jupyterlab-pygments==0.3.0
#  + jupyterlab-server==2.27.3
#  + jupyterlab-widgets==3.0.15
#  + lark==1.3.0
#  + markupsafe==3.0.3
#  + matplotlib-inline==0.1.7
#  + mistune==3.1.4
#  + multidict==6.7.0
#  + nbclient==0.10.2
#  + nbconvert==7.16.6
#  + nbformat==5.10.4
#  + nest-asyncio==1.6.0
#  + notebook==7.4.7
#  + notebook-shim==0.2.4
#  + numpy==2.3.4
#  + oauthlib==3.3.1
#  + packaging==25.0
#  + pandas==2.3.3
#  + pandocfilters==1.5.1
#  + parso==0.8.5
#  + pexpect==4.9.0
#  + platformdirs==4.5.0
#  + prometheus-client==0.23.1
#  + prompt-toolkit==3.0.52
#  + propcache==0.4.1
#  + proto-plus==1.26.1
#  + protobuf==6.33.0
#  + psutil==7.1.1
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pycparser==2.23
#  + pydantic==2.12.3
#  + pydantic-core==2.41.4
#  + pygments==2.19.2
#  + python-dateutil==2.9.0.post0
#  + python-json-logger==4.0.0
#  + pytz==2025.2
#  + pyyaml==6.0.3
#  + pyzmq==27.1.0
#  + referencing==0.37.0
#  + requests==2.32.5
#  + requests-oauthlib==2.0.0
#  + rfc3339-validator==0.1.4
#  + rfc3986-validator==0.1.1
#  + rfc3987-syntax==1.1.0
#  + rpds-py==0.27.1
#  + rsa==4.9.1
#  + scikit-learn==1.7.2
#  + scipy==1.16.2
#  + send2trash==1.8.3
#  + setuptools==80.9.0
#  + shapely==2.1.2
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.8
#  + stack-data==0.6.3
#  + tenacity==9.1.2
#  + terminado==0.18.1
#  + threadpoolctl==3.6.0
#  + tinycss2==1.4.0
#  + tornado==6.5.2
#  + traitlets==5.14.3
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + tzdata==2025.2
#  + uri-template==1.3.0
#  + urllib3==2.5.0
#  + wcwidth==0.2.14
#  + webcolors==24.11.1
#  + webencodings==0.5.1
#  + websocket-client==1.9.0
#  + websockets==15.0.1
#  + widgetsnbextension==4.0.14
#  + yarl==1.22.0
# Removing intermediate container ada1ced547a0
#  ---> 7ec65bd52628
# Step 6/10 : RUN uv add fastapi
#  ---> Running in 5d1b38b031ce
# Resolved 151 packages in 1.10s
# Prepared 2 packages in 74ms
# Installed 2 packages in 5ms
#  + fastapi==0.119.1
#  + starlette==0.48.0
# Removing intermediate container 5d1b38b031ce
#  ---> e13ff0e22d6d
# Step 7/10 : RUN uv add uvicorn[standard]
#  ---> Running in 630c7c7978b4
# Resolved 157 packages in 263ms
# Downloading uvloop (4.2MiB)
#  Downloading uvloop
# Prepared 6 packages in 218ms
# Installed 6 packages in 8ms
#  + click==8.3.0
#  + httptools==0.7.1
#  + python-dotenv==1.1.1
#  + uvicorn==0.38.0
#  + uvloop==0.22.1
#  + watchfiles==1.1.1
# Removing intermediate container 630c7c7978b4
#  ---> 713a86ce61b9
# Step 8/10 : COPY app/ ./app/
#  ---> 9cf2d3a1a155
# Step 9/10 : EXPOSE 8086
#  ---> Running in 91675025c834
# Removing intermediate container 91675025c834
#  ---> eb36f3e91a44
# Step 10/10 : CMD ["uv", "run", "uvicorn", "app.main:app", "--host", "0.0.0.0", "--port", "8086"]
#  ---> Running in cdf2e6ac4f45
# Removing intermediate container cdf2e6ac4f45
#  ---> c791f3958aa6
# Successfully built c791f3958aa6
# Successfully tagged us-central1-docker.pkg.dev/office-cloud-project/cloud-office-ml-docker-repo/coml-image-name:latest
# PUSH
# Pushing us-central1-docker.pkg.dev/office-cloud-project/cloud-office-ml-docker-repo/coml-image-name
# The push refers to repository [us-central1-docker.pkg.dev/office-cloud-project/cloud-office-ml-docker-repo/coml-image-name]
# 63f210a970c0: Preparing
# 91ee06003230: Preparing
# 90c1c6f0386d: Preparing
# d65fdecbe927: Preparing
# 194eb538b065: Preparing
# df05b4c335ab: Preparing
# ca3722481ce8: Preparing
# 7770fbb416af: Preparing
# acbbee3380a1: Preparing
# 16dffb6a6636: Preparing
# d7c97cb6f1fe: Preparing
# df05b4c335ab: Waiting
# ca3722481ce8: Waiting
# 7770fbb416af: Waiting
# acbbee3380a1: Waiting
# 16dffb6a6636: Waiting
# d7c97cb6f1fe: Waiting
# 63f210a970c0: Pushed
# 194eb538b065: Pushed
# 91ee06003230: Pushed
# df05b4c335ab: Pushed
# 90c1c6f0386d: Pushed
# 7770fbb416af: Pushed
# 16dffb6a6636: Pushed
# ca3722481ce8: Pushed
# acbbee3380a1: Pushed
# d7c97cb6f1fe: Pushed
# d65fdecbe927: Pushed
# latest: digest: sha256:813a4a886d60c6528d104d0f3bb7214421c413ef1c148dc70abe8458c2ccd144 size: 2632
# DONE
# --------------------------------------------------------------------------------
# ID                                    CREATE_TIME                DURATION  SOURCE                                                                                              IMAGES                                                                                                 STATUS
# f47623eb-2516-42d7-867a-88f23b2a4e9a  2025-10-23T08:52:54+00:00  1M24S     gs://office-cloud-project_cloudbuild/source/1761209572.666546-005d921acf8d4527b70d43834dfbfb47.tgz  us-central1-docker.pkg.dev/office-cloud-project/cloud-office-ml-docker-repo/coml-image-name (+1 more)  SUCCESS

# %%
model = aiplatform.Model.upload(
    display_name=MODEL_DISPLAY_NAME,
    artifact_uri=f"{BUCKET_URI}/{MODEL_ARTIFACT_DIR}",
    serving_container_image_uri=f"{LOCATION}-docker.pkg.dev/{PROJECT_ID}/{REPOSITORY}/{IMAGE}",
)
# Out:
# Creating Model
# Create Model backing LRO: projects/485739110011/locations/us-central1/models/4839323408283992064/operations/4892136473639256064
# Model created. Resource name: projects/485739110011/locations/us-central1/models/4839323408283992064@1
# To use this Model in another session:
# model = aiplatform.Model('projects/485739110011/locations/us-central1/models/4839323408283992064@1')

# %%
endpoint = model.deploy(
    machine_type="n1-standard-4"
)
# Out:
# Creating Endpoint
# Create Endpoint backing LRO: projects/485739110011/locations/us-central1/endpoints/434112479413403648/operations/4941359410191532032
# Endpoint created. Resource name: projects/485739110011/locations/us-central1/endpoints/434112479413403648
# To use this Endpoint in another session:
# endpoint = aiplatform.Endpoint('projects/485739110011/locations/us-central1/endpoints/434112479413403648')
# Deploying model to Endpoint : projects/485739110011/locations/us-central1/endpoints/434112479413403648
# Deploy Endpoint model backing LRO: projects/485739110011/locations/us-central1/endpoints/434112479413403648/operations/8074175900981133312
# ---------------------------------------------------------------------------
# _OperationNotComplete                     Traceback (most recent call last)
# File ~/cloud-office-ml/.venv/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File ~/cloud-office-ml/.venv/lib/python3.12/site-packages/google/api_core/future/polling.py:120, in PollingFuture._done_or_raise(self, retry)
#     119 if not self.done(retry=retry):
# --> 120     raise _OperationNotComplete()
#
# _OperationNotComplete:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 endpoint = model.deploy(
#       2     machine_type="n1-standard-2"
#       3 )
#
# File ~/cloud-office-ml/.venv/lib/python3.12/site-packages/google/cloud/aiplatform/models.py:5978, in Model.deploy(self, endpoint, deployed_model_display_name, traffic_percentage, traffic_split, machine_type, min_replica_count, max_replica_count, accelerator_type, accelerator_count, gpu_partition_size, tpu_topology, service_account, explanation_metadata, explanation_parameters, metadata, encryption_spec_key_name, network, sync, deploy_request_timeout, autoscaling_target_cpu_utilization, autoscaling_target_accelerator_duty_cycle, autoscaling_target_request_count_per_minute, autoscaling_target_pubsub_num_undelivered_messages, autoscaling_pubsub_subscription_labels, enable_access_logging, disable_container_logging, private_service_connect_config, deployment_resource_pool, reservation_affinity_type, reservation_affinity_key, reservation_affinity_values, spot, fast_tryout_enabled, system_labels, required_replica_count)
#    5967         raise ValueError(
#    5968             "Traffic splitting is not yet supported for PSA based PrivateEndpoint. "
#    5969             "Try calling deploy() without providing `traffic_split`. "
#    5970             "A maximum of one model can be deployed to each private Endpoint."
#    5971         )
#    5973 explanation_spec = _explanation_utils.create_and_validate_explanation_spec(
#    5974     explanation_metadata=explanation_metadata,
#    5975     explanation_parameters=explanation_parameters,
#    5976 )
# -> 5978 return self._deploy(
#    5979     endpoint=endpoint,
#    5980     deployed_model_display_name=deployed_model_display_name,
#    5981     traffic_percentage=traffic_percentage,
#    5982     traffic_split=traffic_split,
#    5983     machine_type=machine_type,
#    5984     min_replica_count=min_replica_count,
#    5985     max_replica_count=max_replica_count,
#    5986     accelerator_type=accelerator_type,
#    5987     accelerator_count=accelerator_count,
#    5988     gpu_partition_size=gpu_partition_size,
#    5989     tpu_topology=tpu_topology,
#    5990     reservation_affinity_type=reservation_affinity_type,
#    5991     reservation_affinity_key=reservation_affinity_key,
#    5992     reservation_affinity_values=reservation_affinity_values,
#    5993     service_account=service_account,
#    5994     explanation_spec=explanation_spec,
#    5995     metadata=metadata,
#    5996     encryption_spec_key_name=encryption_spec_key_name
#    5997     or initializer.global_config.encryption_spec_key_name,
#    5998     network=network,
#    5999     sync=sync,
#    6000     deploy_request_timeout=deploy_request_timeout,
#    6001     autoscaling_target_cpu_utilization=autoscaling_target_cpu_utilization,
#    6002     autoscaling_target_accelerator_duty_cycle=autoscaling_target_accelerator_duty_cycle,
#    6003     autoscaling_target_request_count_per_minute=autoscaling_target_request_count_per_minute,
#    6004     autoscaling_target_pubsub_num_undelivered_messages=autoscaling_target_pubsub_num_undelivered_messages,
#    6005     autoscaling_pubsub_subscription_labels=autoscaling_pubsub_subscription_labels,
#    6006     spot=spot,
#    6007     enable_access_logging=enable_access_logging,
#    6008     disable_container_logging=disable_container_logging,
#    6009     private_service_connect_config=private_service_connect_config,
#    6010     deployment_resource_pool=deployment_resource_pool,
#    6011     fast_tryout_enabled=fast_tryout_enabled,
#    6012     system_labels=system_labels,
#    6013     required_replica_count=required_replica_count,
#    6014 )
#
# File ~/cloud-office-ml/.venv/lib/python3.12/site-packages/google/cloud/aiplatform/base.py:862, in optional_sync.<locals>.optional_run_in_thread.<locals>.wrapper(*args, **kwargs)
#     860     if self:
#     861         VertexAiResourceNounWithFutureManager.wait(self)
# --> 862     return method(*args, **kwargs)
#     864 # callbacks to call within the Future (in same Thread)
#     865 internal_callbacks = []
#
# File ~/cloud-office-ml/.venv/lib/python3.12/site-packages/google/cloud/aiplatform/models.py:6244, in Model._deploy(self, endpoint, deployed_model_display_name, traffic_percentage, traffic_split, machine_type, min_replica_count, max_replica_count, accelerator_type, accelerator_count, gpu_partition_size, tpu_topology, reservation_affinity_type, reservation_affinity_key, reservation_affinity_values, service_account, explanation_spec, metadata, encryption_spec_key_name, network, sync, deploy_request_timeout, autoscaling_target_cpu_utilization, autoscaling_target_accelerator_duty_cycle, autoscaling_target_request_count_per_minute, autoscaling_target_pubsub_num_undelivered_messages, autoscaling_pubsub_subscription_labels, spot, enable_access_logging, disable_container_logging, private_service_connect_config, deployment_resource_pool, fast_tryout_enabled, system_labels, required_replica_count)
#    6232         endpoint = PrivateEndpoint.create(
#    6233             display_name=display_name,
#    6234             network=network,
#    (...)   6239             private_service_connect_config=private_service_connect_config,
#    6240         )
#    6242 _LOGGER.log_action_start_against_resource("Deploying model to", "", endpoint)
# -> 6244 endpoint._deploy_call(
#    6245     endpoint.api_client,
#    6246     endpoint.resource_name,
#    6247     self,
#    6248     endpoint._gca_resource.traffic_split,
#    6249     network=network or endpoint.network,
#    6250     deployed_model_display_name=deployed_model_display_name,
#    6251     traffic_percentage=traffic_percentage,
#    6252     traffic_split=traffic_split,
#    6253     machine_type=machine_type,
#    6254     min_replica_count=min_replica_count,
#    6255     max_replica_count=max_replica_count,
#    6256     accelerator_type=accelerator_type,
#    6257     accelerator_count=accelerator_count,
#    6258     gpu_partition_size=gpu_partition_size,
#    6259     tpu_topology=tpu_topology,
#    6260     reservation_affinity_type=reservation_affinity_type,
#    6261     reservation_affinity_key=reservation_affinity_key,
#    6262     reservation_affinity_values=reservation_affinity_values,
#    6263     service_account=service_account,
#    6264     explanation_spec=explanation_spec,
#    6265     metadata=metadata,
#    6266     deploy_request_timeout=deploy_request_timeout,
#    6267     autoscaling_target_cpu_utilization=autoscaling_target_cpu_utilization,
#    6268     autoscaling_target_accelerator_duty_cycle=autoscaling_target_accelerator_duty_cycle,
#    6269     autoscaling_target_request_count_per_minute=autoscaling_target_request_count_per_minute,
#    6270     autoscaling_target_pubsub_num_undelivered_messages=autoscaling_target_pubsub_num_undelivered_messages,
#    6271     autoscaling_pubsub_subscription_labels=autoscaling_pubsub_subscription_labels,
#    6272     spot=spot,
#    6273     enable_access_logging=enable_access_logging,
#    6274     disable_container_logging=disable_container_logging,
#    6275     deployment_resource_pool=deployment_resource_pool,
#    6276     fast_tryout_enabled=fast_tryout_enabled,
#    6277     system_labels=system_labels,
#    6278     required_replica_count=required_replica_count,
#    6279 )
#    6281 _LOGGER.log_action_completed_against_resource("model", "deployed", endpoint)
#    6283 endpoint._sync_gca_resource()
#
# File ~/cloud-office-ml/.venv/lib/python3.12/site-packages/google/cloud/aiplatform/models.py:2237, in Endpoint._deploy_call(cls, api_client, endpoint_resource_name, model, endpoint_resource_traffic_split, network, deployed_model_display_name, traffic_percentage, traffic_split, machine_type, min_replica_count, max_replica_count, accelerator_type, accelerator_count, gpu_partition_size, tpu_topology, reservation_affinity_type, reservation_affinity_key, reservation_affinity_values, service_account, explanation_spec, metadata, deploy_request_timeout, autoscaling_target_cpu_utilization, autoscaling_target_accelerator_duty_cycle, autoscaling_target_request_count_per_minute, autoscaling_target_pubsub_num_undelivered_messages, autoscaling_pubsub_subscription_labels, spot, enable_access_logging, disable_container_logging, deployment_resource_pool, fast_tryout_enabled, system_labels, required_replica_count)
#    2225 operation_future = api_client.deploy_model(
#    2226     endpoint=endpoint_resource_name,
#    2227     deployed_model=deployed_model,
#    (...)   2230     timeout=deploy_request_timeout,
#    2231 )
#    2233 _LOGGER.log_action_started_against_resource_with_lro(
#    2234     "Deploy", "model", cls, operation_future
#    2235 )
# -> 2237 operation_future.result(timeout=None)
#
# File ~/cloud-office-ml/.venv/lib/python3.12/site-packages/google/api_core/future/polling.py:256, in PollingFuture.result(self, timeout, retry, polling)
#     144 def result(self, timeout=_DEFAULT_VALUE, retry=None, polling=None):
#     145     """Get the result of the operation.
#     146
#     147     This method will poll for operation status periodically, blocking if
#    (...)    253             the timeout is reached before the operation completes.
#     254     """
# --> 256     self._blocking_poll(timeout=timeout, retry=retry, polling=polling)
#     258     if self._exception is not None:
#     259         # pylint: disable=raising-bad-type
#     260         # Pylint doesn't recognize that this is valid in this case.
#     261         raise self._exception
#
# File ~/cloud-office-ml/.venv/lib/python3.12/site-packages/google/api_core/future/polling.py:137, in PollingFuture._blocking_poll(self, timeout, retry, polling)
#     134     polling = polling.with_timeout(timeout)
#     136 try:
# --> 137     polling(self._done_or_raise)(retry=retry)
#     138 except exceptions.RetryError:
#     139     raise concurrent.futures.TimeoutError(
#     140         f"Operation did not complete within the designated timeout of "
#     141         f"{polling.timeout} seconds."
#     142     )
#
# File ~/cloud-office-ml/.venv/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~/cloud-office-ml/.venv/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:167, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     156 next_sleep = _retry_error_helper(
#     157     exc,
#     158     deadline,
#    (...)    164     timeout,
#     165 )
#     166 # if exception not raised, sleep before next attempt
# --> 167 time.sleep(next_sleep)
#
# KeyboardInterrupt:

# %%
# local cleanup
! rm -rf app/
! rm -rf test_request.py
! rm -rf Dockerfile
